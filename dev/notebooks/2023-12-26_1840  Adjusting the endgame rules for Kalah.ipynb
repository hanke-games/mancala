# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#" data-toc-modified-id="-1"></a></span></li></ul></div>

# %%
## Add the parent directory to the 
import sys, os
sys.path.append(os.path.join(sys.path[0],'..', '..'))

# %%
from mancala import *

# %%
game3 = play_kalah(6,4)
# Out:
#             13  12  11  10   9   8
#       ------------------------------------
#              4   4   4   4   4   4
#          0                           0
#              4   4   4   4   4   4
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  3
#
#             13  12  11  10   9   8
#       ------------------------------------
#              4   4   4   4   4   4
#          0                           1
#              4   4   0   5   5   5
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              4   4   5   5   5   5
#          0                           2
#              4   4   0   5   5   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              5   5   6   6   0   5
#          1                           2
#              4   4   0   5   5   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  8
#
#             13  12  11  10   9   8
#       ------------------------------------
#              6   6   7   7   1   0
#          1                           2
#              4   4   0   5   5   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              6   6   7   7   1   0
#          1                           2
#              4   0   1   6   6   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   6   7   7   1   0
#          2                           2
#              5   1   2   7   7   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   6   7   7   1   0
#          2                           3
#              5   1   2   7   7   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   6   7   7   1   0
#          2                           3
#              0   2   3   8   8   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   0   1   0
#          3                           3
#              1   3   4   8   8   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   0   1   0
#          3                           4
#              1   3   4   8   8   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  3
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   0   1   0
#          3                           5
#              1   3   0   9   9   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   0   1   0
#          3                           6
#              1   3   0   9   9   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   0   1   0
#          3                           6
#              0   4   0   9   9   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   1   0   0
#         12                           6
#              0   4   0   0   9   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   7   8   1   0   0
#         12                           6
#              0   0   1   1  10   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   7   8   1   0   0
#         13                           6
#              0   0   1   1  10   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  12
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   8   1   0   0
#         14                           6
#              1   1   2   2  11   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   8   1   0   0
#         14                           7
#              1   1   2   2  11   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  4
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   8   1   0   0
#         14                           7
#              1   1   2   0  12   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
#             13  12  11  10   9   8
#       ------------------------------------
#              2   1   0   1   0   0
#         15                           7
#              2   2   3   1  13   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              2   1   0   1   0   0
#         15                           8
#              2   2   3   1  13   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  3
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              2   1   0   1   0   0
#         15                           8
#              2   2   0   2  14   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   1   0   0
#         16                           8
#              3   2   0   2  14   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   1   0   0
#         16                           9
#              3   2   0   2  14   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   1   0   0
#         16                           9
#              0   3   1   3  14   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   1   0   0   0
#         17                           9
#              0   3   0   3  14   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   1   1   0   0   0
#         17                           9
#              0   0   1   4  15   0
#       ------------------------------------
#              1   2   3   4   5   6
# Your move (Q to quit)?  12
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   1   0   0   0
#         17                           9
#              0   0   1   4  15   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  3
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   1   0   0   0
#         17                           9
#              0   0   0   5  15   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   1   0   0   0   0
#         17                           9
#              0   0   0   5  15   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  4
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   1   0   0   1   1
#         17                          10
#              0   0   0   0  16   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   1   0   1   0   1
#         17                          10
#              0   0   0   0  16   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   1   0   1   0   1
#         17                          11
#              0   0   0   0  16   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  5
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              2   2   1   2   1   3
#         17                          13
#              1   1   1   1   1   2
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   2   1   2   1   3
#         18                          13
#              2   1   1   1   1   2
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   2   1   2   1   4
#         18                          14
#              2   1   1   1   1   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  12
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   1   2   1   4
#         19                          14
#              2   1   1   1   1   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   2   1   4
#         20                          14
#              2   1   1   1   1   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   2   1   4
#         20                          14
#              2   1   1   1   1   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   2   0   1   4
#         21                          14
#              2   0   1   1   1   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   1   2   0   1   4
#         21                          14
#              0   1   2   1   1   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  8
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   2   3   1   2   0
#         21                          14
#              0   1   2   1   1   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  3
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   2   3   1   2   0
#         21                          14
#              0   1   0   2   2   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   3   0   1   2   0
#         22                          14
#              0   1   0   2   2   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   3   0   1   2   0
#         23                          14
#              0   1   0   2   2   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  12
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   1   2   0
#         24                          14
#              1   1   0   2   2   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  5
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   1   2   0
#         24                          15
#              1   1   0   2   0   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   1   2   0
#         24                          16
#              1   1   0   2   0   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  4
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   1   2   0
#         24                          16
#              1   1   0   0   1   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   1   2   0
#         25                          16
#              1   1   0   0   1   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   0   2   0
#         25                          16
#              1   1   0   0   1   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   0   2   0
#         25                          17
#              1   1   0   0   1   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  5
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   0   2   0
#         25                          17
#              1   1   0   0   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   0   2   0
#         26                          17
#              1   0   0   0   0   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   0   2   0
#         26                          18
#              1   0   0   0   0   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   0   2   0
#         26                          19
#              0   1   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   1   0   0
#         26                          19
#              0   1   0   0   0   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   1   0   0
#         26                          20
#              0   0   1   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   0   1   0   0   0
#         27                          20
#              0   0   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   1   0   0   0   0
#         27                          20
#              0   0   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  12
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   0   0   0
#         27                          20
#              0   0   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   0   0   0
#         28                          20
#              0   0   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6

# %%
game3
# Out:
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   0   0   0
#         28                          20
#              0   0   0   0   0   0
#       ------------------------------------
#              1   2   3   4   5   6

# %%
print(game3.history_list())
# Out:
# [3, 6, 9, 8, 2, 13, 6, 1, 10, 6, 3, 6, 1, 9, 2, 13, 12, 6, 4, 11, 6, 3, 13, 6, 1, 10, 2, 12, 3, 11, 4, 9, 6, 5, 13, 6, 12, 13, 10, 1, 8, 3, 11, 13, 12, 5, 6, 4, 13, 10, 6, 5, 11, 6, 1, 9, 2, 10, 11, 12, 13]

# %%
print(game1.history_list())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qf/k7dgnp855m3cn5p4g2mtn6wh0000gn/T/ipykernel_45624/2185322556.py in <module>
# ----> 1 print(game1.history_list())
#
# NameError: name 'game1' is not defined

# %% [markdown]
# ######

# %%
game1 = play_kalah(6,4)
# Out:
#             13  12  11  10   9   8
#       ------------------------------------
#              4   4   4   4   4   4
#          0                           0
#              4   4   4   4   4   4
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              4   4   4   5   5   5
#          0                           1
#              4   4   4   4   4   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              5   5   5   6   0   5
#          1                           1
#              4   4   4   4   4   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   5   5   6   0   5
#          2                           1
#              5   5   5   5   4   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   5   5   6   0   5
#          2                           2
#              5   0   6   6   5   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   5   5   6   0   5
#          2                           3
#              5   0   6   6   5   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   5   5   6   0   0
#          2                           8
#              0   1   7   7   6   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   6   0   6   0   0
#          3                           8
#              1   2   7   7   6   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   6   0   6   0   0
#          3                           9
#              1   2   7   7   6   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  5
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   6   1   7   1   1
#          3                          10
#              1   2   7   7   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   6   1   7   1   1
#          4                          10
#              1   2   7   7   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   2   0   1   1
#          5                          10
#              2   3   8   7   0   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   7   2   0   1   1
#          5                          11
#              2   3   8   7   0   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  1
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   7   2   0   1   1
#          5                          11
#              0   4   9   7   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   7   2   0   1   1
#          6                          11
#              0   4   9   7   0   0
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  9
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   7   2   1   0   1
#         13                          11
#              0   4   9   0   0   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   7   2   1   0   0
#         13                          12
#              0   0  10   1   1   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  10
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   7   3   0   0   0
#         13                          12
#              0   0  10   1   1   1
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  6
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   7   3   0   0   0
#         13                          13
#              0   0  10   1   1   0
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  5
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   7   3   0   0   0
#         13                          13
#              0   0  10   1   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  11
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   8   0   0   0   0
#         14                          13
#              0   0  10   1   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              0   8   0   0   0   0
#         15                          13
#              0   0  10   1   0   1
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  12
#
#             13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   0   0   0
#         16                          13
#              1   1  11   2   1   2
#       ------------------------------------
# s -->        1   2   3   4   5   6
#
#
# Your move (Q to quit)?  2
#
# n -->       13  12  11  10   9   8
#       ------------------------------------
#              1   0   0   0   0   0
#         16                          13
#              1   0  12   2   1   2
#       ------------------------------------
#              1   2   3   4   5   6
#
#
# Your move (Q to quit)?  13
#
#             13  12  11  10   9   8
#       ------------------------------------
#              0   0   0   0   0   0
#         17                          13
#              1   0  12   2   1   2
#       ------------------------------------
# s -->        1   2   3   4   5   6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qf/k7dgnp855m3cn5p4g2mtn6wh0000gn/T/ipykernel_45624/2113310730.py in <module>
# ----> 1 game1 = play_kalah(6,4)
#
# ~/Documents/Code_Repositories/mancala/dev/notebooks/../../mancala/game.py in play_kalah(m, n)
#      20         ## Get the next move
#      21         while not move_int_flag:
# ---> 22             move_str = input("Your move (Q to quit)?  ")
#      23             try:
#      24                 move_int = int(move_str)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1173                 "raw_input was called, but this frontend does not support input requests."
#    1174             )
# -> 1175         return self._input_request(
#    1176             str(prompt),
#    1177             self._parent_ident["shell"],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1215             except KeyboardInterrupt:
#    1216                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1217                 raise KeyboardInterrupt("Interrupted by user") from None
#    1218             except Exception:
#    1219                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
